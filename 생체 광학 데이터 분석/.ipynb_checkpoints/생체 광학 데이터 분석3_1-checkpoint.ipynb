# %% [markdown]
# # 0. 라이브러리 및 데이터

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from tqdm import tqdm_notebook

from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.model_selection import KFold, cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
import lightgbm as lgb

import warnings
warnings.filterwarnings(action='ignore')

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')
submission = pd.read_csv('./data/sample_submission.csv')

# id : 구분자
# rho : 측정 거리 (단위: mm)
# src : 광원 스펙트럼 (650 nm ~ 990 nm)
# dst : 측정 스펙트럼 (650 nm ~ 990 nm)

# hhb : 디옥시헤모글로빈 농도
# hbo2 : 옥시헤모글로빈 농도
# ca : 칼슘 농도
# na : 나트륨 농도

# %%
train.head()
# Out:
#    id  rho  650_src  660_src  670_src  680_src  690_src  700_src  710_src  \
# 0   0   25  0.37950  0.42993  0.52076  0.57166  0.67818  0.75476  0.83580
# 1   1   10  0.00000  0.00000  0.01813  0.00000  0.00000  0.01974  0.00321
# 2   2   25  0.00000  0.03289  0.02416  0.03610  0.05843  0.09015  0.14944
# 3   3   10  0.27503  0.31281  0.32898  0.41041  0.46587  0.52769  0.64369
# 4   4   15  1.01521  1.00872  0.98930  0.98874  1.01773  1.01632  1.00009
#
#    720_src  ...       940_dst       950_dst       960_dst       970_dst  \
# 0  0.93623  ...           NaN  0.000000e+00           NaN  1.067504e-18
# 1  0.00000  ...  1.343132e-08  6.112685e-09  2.130547e-09           NaN
# 2  0.18578  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 3  0.73562  ...  2.245998e-10  1.299511e-10  7.782625e-11           NaN
# 4  0.98217  ...  1.457955e-13  8.769053e-14           NaN  1.330237e-13
#
#         980_dst       990_dst    hhb  hbo2     ca    na
# 0  5.998949e-18  4.378513e-17   5.59  4.32   8.92  4.29
# 1  9.710091e-09           NaN   0.00  2.83   7.25  4.64
# 2  1.329725e-18           NaN  10.64  3.00   8.40  5.16
# 3  4.088921e-10           NaN   5.67  4.01   5.05  4.35
# 4           NaN           NaN  11.97  4.41  10.78  2.42
#
# [5 rows x 76 columns]

# %%
test.head()
# Out:
#       id  rho  650_src  660_src  670_src  680_src  690_src  700_src  710_src  \
# 0  10000   15  0.15406  0.23275  0.30977  0.42949  0.51264  0.62558  0.74340
# 1  10001   15  0.48552  0.56939  0.67575  0.79089  0.85114  0.92581  0.98071
# 2  10002   10  0.46883  0.56085  0.62442  0.73172  0.81724  0.91517  0.94801
# 3  10003   10  0.06905  0.07517  0.10226  0.14905  0.16182  0.19659  0.26085
# 4  10004   25  0.00253  0.00757  0.01649  0.00128  0.00000  0.00000  0.00105
#
#    720_src  ...       900_dst       910_dst       920_dst       930_dst  \
# 0  0.85418  ...  0.000000e+00  0.000000e+00  1.432248e-14  0.000000e+00
# 1  0.98177  ...  1.036013e-13           NaN  2.830975e-14  1.114337e-13
# 2  0.99108  ...           NaN           NaN           NaN           NaN
# 3  0.36753  ...  1.651177e-11  7.282747e-12  5.010879e-12           NaN
# 4  0.01975  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#         940_dst       950_dst       960_dst       970_dst       980_dst  \
# 0  0.000000e+00  6.332117e-15  1.429966e-14  0.000000e+00           NaN
# 1  4.825731e-14           NaN  2.282485e-14  7.348414e-14  1.259055e-13
# 2  1.569208e-11  6.242378e-12           NaN  1.219010e-11           NaN
# 3  1.571023e-11  0.000000e+00  0.000000e+00  3.304247e-12  4.106134e-11
# 4  3.732057e-17  4.110605e-17  0.000000e+00  0.000000e+00  1.910775e-16
#
#         990_dst
# 0  7.320236e-14
# 1  2.349874e-13
# 2           NaN
# 3           NaN
# 4  2.215673e-15
#
# [5 rows x 72 columns]

# %%
print ("Size of train data : {}" .format(train.shape))
print ("Size of test data : {}" .format(test.shape))
# Out:
# Size of train data : (10000, 76)
# Size of test data : (10000, 72)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 76 columns):
# id         10000 non-null int64
# rho        10000 non-null int64
# 650_src    10000 non-null float64
# 660_src    10000 non-null float64
# 670_src    10000 non-null float64
# 680_src    10000 non-null float64
# 690_src    10000 non-null float64
# 700_src    10000 non-null float64
# 710_src    10000 non-null float64
# 720_src    10000 non-null float64
# 730_src    10000 non-null float64
# 740_src    10000 non-null float64
# 750_src    10000 non-null float64
# 760_src    10000 non-null float64
# 770_src    10000 non-null float64
# 780_src    10000 non-null float64
# 790_src    10000 non-null float64
# 800_src    10000 non-null float64
# 810_src    10000 non-null float64
# 820_src    10000 non-null float64
# 830_src    10000 non-null float64
# 840_src    10000 non-null float64
# 850_src    10000 non-null float64
# 860_src    10000 non-null float64
# 870_src    10000 non-null float64
# 880_src    10000 non-null float64
# 890_src    10000 non-null float64
# 900_src    10000 non-null float64
# 910_src    10000 non-null float64
# 920_src    10000 non-null float64
# 930_src    10000 non-null float64
# 940_src    10000 non-null float64
# 950_src    10000 non-null float64
# 960_src    10000 non-null float64
# 970_src    10000 non-null float64
# 980_src    10000 non-null float64
# 990_src    10000 non-null float64
# 650_dst    8052 non-null float64
# 660_dst    8012 non-null float64
# 670_dst    8069 non-null float64
# 680_dst    8025 non-null float64
# 690_dst    7997 non-null float64
# 700_dst    8034 non-null float64
# 710_dst    8054 non-null float64
# 720_dst    7954 non-null float64
# 730_dst    7994 non-null float64
# 740_dst    8007 non-null float64
# 750_dst    7929 non-null float64
# 760_dst    7950 non-null float64
# 770_dst    8006 non-null float64
# 780_dst    8055 non-null float64
# 790_dst    7941 non-null float64
# 800_dst    7974 non-null float64
# 810_dst    8010 non-null float64
# 820_dst    7909 non-null float64
# 830_dst    8035 non-null float64
# 840_dst    7955 non-null float64
# 850_dst    7986 non-null float64
# 860_dst    7990 non-null float64
# 870_dst    7980 non-null float64
# 880_dst    8032 non-null float64
# 890_dst    7941 non-null float64
# 900_dst    8001 non-null float64
# 910_dst    7970 non-null float64
# 920_dst    7962 non-null float64
# 930_dst    8022 non-null float64
# 940_dst    7982 non-null float64
# 950_dst    7987 non-null float64
# 960_dst    7992 non-null float64
# 970_dst    7931 non-null float64
# 980_dst    8081 non-null float64
# 990_dst    8013 non-null float64
# hhb        10000 non-null float64
# hbo2       10000 non-null float64
# ca         10000 non-null float64
# na         10000 non-null float64
# dtypes: float64(74), int64(2)
# memory usage: 5.8 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 72 columns):
# id         10000 non-null int64
# rho        10000 non-null int64
# 650_src    10000 non-null float64
# 660_src    10000 non-null float64
# 670_src    10000 non-null float64
# 680_src    10000 non-null float64
# 690_src    10000 non-null float64
# 700_src    10000 non-null float64
# 710_src    10000 non-null float64
# 720_src    10000 non-null float64
# 730_src    10000 non-null float64
# 740_src    10000 non-null float64
# 750_src    10000 non-null float64
# 760_src    10000 non-null float64
# 770_src    10000 non-null float64
# 780_src    10000 non-null float64
# 790_src    10000 non-null float64
# 800_src    10000 non-null float64
# 810_src    10000 non-null float64
# 820_src    10000 non-null float64
# 830_src    10000 non-null float64
# 840_src    10000 non-null float64
# 850_src    10000 non-null float64
# 860_src    10000 non-null float64
# 870_src    10000 non-null float64
# 880_src    10000 non-null float64
# 890_src    10000 non-null float64
# 900_src    10000 non-null float64
# 910_src    10000 non-null float64
# 920_src    10000 non-null float64
# 930_src    10000 non-null float64
# 940_src    10000 non-null float64
# 950_src    10000 non-null float64
# 960_src    10000 non-null float64
# 970_src    10000 non-null float64
# 980_src    10000 non-null float64
# 990_src    10000 non-null float64
# 650_dst    7974 non-null float64
# 660_dst    8040 non-null float64
# 670_dst    7985 non-null float64
# 680_dst    7994 non-null float64
# 690_dst    8015 non-null float64
# 700_dst    8052 non-null float64
# 710_dst    7957 non-null float64
# 720_dst    7986 non-null float64
# 730_dst    7962 non-null float64
# 740_dst    8001 non-null float64
# 750_dst    8035 non-null float64
# 760_dst    8000 non-null float64
# 770_dst    8044 non-null float64
# 780_dst    7980 non-null float64
# 790_dst    7970 non-null float64
# 800_dst    8039 non-null float64
# 810_dst    7966 non-null float64
# 820_dst    7958 non-null float64
# 830_dst    7942 non-null float64
# 840_dst    8053 non-null float64
# 850_dst    7995 non-null float64
# 860_dst    7992 non-null float64
# 870_dst    7937 non-null float64
# 880_dst    7920 non-null float64
# 890_dst    8004 non-null float64
# 900_dst    8024 non-null float64
# 910_dst    8081 non-null float64
# 920_dst    8019 non-null float64
# 930_dst    8000 non-null float64
# 940_dst    8001 non-null float64
# 950_dst    8051 non-null float64
# 960_dst    7980 non-null float64
# 970_dst    8024 non-null float64
# 980_dst    7989 non-null float64
# 990_dst    8030 non-null float64
# dtypes: float64(70), int64(2)
# memory usage: 5.5 MB

# %% [markdown]
# # 1. 탐색적 자료 분석

# %% [markdown]
# ## 1.1 결측치 확인

# %%
train.isnull().sum().plot()

# %%
test.isnull().sum().plot()

# %%
print(train.isnull().sum()[train.isnull().sum().values > 0].index)
# Out:
# Index(['650_dst', '660_dst', '670_dst', '680_dst', '690_dst', '700_dst',
#        '710_dst', '720_dst', '730_dst', '740_dst', '750_dst', '760_dst',
#        '770_dst', '780_dst', '790_dst', '800_dst', '810_dst', '820_dst',
#        '830_dst', '840_dst', '850_dst', '860_dst', '870_dst', '880_dst',
#        '890_dst', '900_dst', '910_dst', '920_dst', '930_dst', '940_dst',
#        '950_dst', '960_dst', '970_dst', '980_dst', '990_dst'],
#       dtype='object')

# %%
print(test.isnull().sum()[test.isnull().sum().values > 0].index)
# Out:
# Index(['650_dst', '660_dst', '670_dst', '680_dst', '690_dst', '700_dst',
#        '710_dst', '720_dst', '730_dst', '740_dst', '750_dst', '760_dst',
#        '770_dst', '780_dst', '790_dst', '800_dst', '810_dst', '820_dst',
#        '830_dst', '840_dst', '850_dst', '860_dst', '870_dst', '880_dst',
#        '890_dst', '900_dst', '910_dst', '920_dst', '930_dst', '940_dst',
#        '950_dst', '960_dst', '970_dst', '980_dst', '990_dst'],
#       dtype='object')

# %% [markdown]
# ## 1.2 데이터의 의미 파악

# %% [markdown]
# ### 1.2.1 광원 스펙트럼

# %%
test.filter(regex='_src$', axis=1).head().T.plot()

# %% [markdown]
# ### 1.2.2 측정 스펙트럼

# %%
test.filter(regex='_dst$', axis=1).head().T.plot()

# %% [markdown]
# # 2. 데이터 정리

# %% [markdown]
# ## 2.1 결측치 보간

# %%
# interpolate():실측값과 실측값 사이의 결측값을 마치 '그라데이션(gradation)' 기법으로 색깔을 조금씩 변화시켜가면서 부드럽게 채워나가는 방법
train = train.interpolate(method='linear', axis=1)
test = test.interpolate(method='linear', axis=1)

test.head()
# Out:
#         id   rho  650_src  660_src  670_src  680_src  690_src  700_src  \
# 0  10000.0  15.0  0.15406  0.23275  0.30977  0.42949  0.51264  0.62558
# 1  10001.0  15.0  0.48552  0.56939  0.67575  0.79089  0.85114  0.92581
# 2  10002.0  10.0  0.46883  0.56085  0.62442  0.73172  0.81724  0.91517
# 3  10003.0  10.0  0.06905  0.07517  0.10226  0.14905  0.16182  0.19659
# 4  10004.0  25.0  0.00253  0.00757  0.01649  0.00128  0.00000  0.00000
#
#    710_src  720_src  ...       900_dst       910_dst       920_dst  \
# 0  0.74340  0.85418  ...  0.000000e+00  0.000000e+00  1.432248e-14
# 1  0.98071  0.98177  ...  1.036013e-13  6.595554e-14  2.830975e-14
# 2  0.94801  0.99108  ...  1.325728e-11  1.386598e-11  1.447468e-11
# 3  0.26085  0.36753  ...  1.651177e-11  7.282747e-12  5.010879e-12
# 4  0.00105  0.01975  ...  0.000000e+00  0.000000e+00  0.000000e+00
#
#         930_dst       940_dst       950_dst       960_dst       970_dst  \
# 0  0.000000e+00  0.000000e+00  6.332117e-15  1.429966e-14  0.000000e+00
# 1  1.114337e-13  4.825731e-14  3.554108e-14  2.282485e-14  7.348414e-14
# 2  1.508338e-11  1.569208e-11  6.242378e-12  9.216241e-12  1.219010e-11
# 3  1.036055e-11  1.571023e-11  0.000000e+00  0.000000e+00  3.304247e-12
# 4  0.000000e+00  3.732057e-17  4.110605e-17  0.000000e+00  0.000000e+00
#
#         980_dst       990_dst
# 0  3.660118e-14  7.320236e-14
# 1  1.259055e-13  2.349874e-13
# 2  1.219010e-11  1.219010e-11
# 3  4.106134e-11  4.106134e-11
# 4  1.910775e-16  2.215673e-15
#
# [5 rows x 72 columns]

# %%
test.filter(regex='_dst$', axis=1).head().T.plot()

# %% [markdown]
# # 3. 데이터 전처리

# %%
test.isnull().sum().plot()

# %%
test.filter(regex='_src$', axis=1).head().T.plot()

# %% [markdown]
# ## 3.1 상관관계 분석

# %%
plt.figure(figsize=(10,20))
sns.heatmap(train.corr().loc['rho':'990_dst', 'hhb':].abs(), fmt='.3f', annot=True, cmap='PuBu')

# %%
plt.figure(figsize=(10, 20))
sns.heatmap(train.corr().loc['rho':'990_dst', 'rho':'990_dst'].abs(), cmap='PuBu')

# %% [markdown]
# ## 이상치 제거

# %%
# columns = train.columns.drop('id')
# sns.set()
# for col in columns:
#     fig,ax = plt.subplots(1, 1, figsize=(20,4))
#     sns.distplot(train[col])

# %%
# # IQR을 이용하여 이상치 탐색
# # https://hong-yp-ml-records.tistory.com/15?category=819005

# from collections import Counter 

# def detect_outliers(df, n, features): 
#     outlier_indices = []
    
#     for col in features: 
#         Q1 = np.percentile(df[col], 25)
#         Q3 = np.percentile(df[col], 75) 
#         IQR = Q3 - Q1
                
#         outlier_step = 1.5 * IQR
#         outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step)].index 
#         outlier_indices.extend(outlier_list_col) 
    
#     outlier_indices = Counter(outlier_indices) 
#     multiple_outliers = list(k for k, v in outlier_indices.items() if v > n) 
    
#     return multiple_outliers

# %%
# train_Outliers = detect_outliers(train, 2, columns)
# train.loc[train_Outliers]
# Out:
#           id   rho  650_src  660_src  670_src  680_src  690_src  700_src  \
#
ns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['features'] = X_train.columns

vif.sort_values(by='VIF Factor', ascending=False)
# Out:
#      VIF Factor features
# 33  1660.044156  810_src
# 29  1648.009709  790_src
# 41  1639.554030  850_src
# 37  1636.191962  830_src
# 27  1633.658288  780_src
# ..          ...      ...
# 2      1.973573  660_dst
# 0      1.701240  650_dst
# 68     1.696264  990_dst
# 8      1.348957  690_dst
# 10     1.018359  700_dst
#
# [71 rows x 2 columns]

# %%
vif.plot()

# %%
# _src 변수끼리 다중공선성 확인
X_train2 = train.loc[:, '650_src':'990_src']
vif2 = pd.DataFrame()
vif2['VIF Factor'] = [variance_inflation_factor(X_train2.values, i) for i in range(X_train2.shape[1])]
vif2['features'] = X_train2.columns

vif2.sort_values(by='VIF Factor', ascending=False)
# Out:
#      VIF Factor features
# 16  1641.691277  810_src
# 14  1635.053032  790_src
# 13  1625.251552  780_src
# 20  1623.180937  850_src
# 15  1616.884069  800_src
# 18  1612.500522  830_src
# 12  1589.024430  770_src
# 19  1575.291222  840_src
# 11  1572.640161  760_src
# 24  1571.971326  890_src
# 22  1568.182388  870_src
# 21  1561.913479  860_src
# 23  1518.298150  880_src
# 17  1513.685136  820_src
# 25  1492.151906  900_src
# 26  1484.006310  910_src
# 9   1479.179577  740_src
# 10  1430.695562  750_src
# 27  1364.063989  920_src
# 8   1360.433785  730_src
# 7   1314.583005  720_src
# 28  1283.149885  930_src
# 29  1271.627335  940_src
# 30  1208.714602  950_src
# 6   1180.785387  710_src
# 31  1128.316027  960_src
# 5   1122.534237  700_src
# 4   1084.403795  690_src
# 32  1015.248381  970_src
# 3    982.519168  680_src
# 2    910.383144  670_src
# 33   860.646864  980_src
# 1    780.329963  660_src
# 34   347.209118  990_src
# 0    328.094328  650_src

# %%
columns = X_train2.columns
sns.set()
for col in columns:
    fig,ax = plt.subplots(1, 1, figsize=(20,4))
    sns.distplot(train[col])

# %%
train_src = train.filter(regex='_src$', axis=1)
test_src = test.filter(regex='_src$', axis=1)

# src변수 5개씩 잘라 평균값내서 mean_src 추가
# 5개씩 가장 분포가 비슷해보여서
train_copy = train.copy()
test_copy = test.copy()

for idx in range(0,31,5):
    avg = []
    for i in range(len(train_src)):
        avg.append(train_src.iloc[i, idx:idx+5].mean())
    train_copy[f'{int(idx/5)+1}_mean_src'] = avg

# %%
# test 
for idx in range(0,31,5):
    avg = []
    for i in range(len(test_src)):
        avg.append(test_src.iloc[i, idx:idx+5].mean())
    test_copy[f'{int(idx/5)+1}_mean_src'] = avg

# %%
# _src 변수 제거
train_copy2 = train_copy.copy()
drops = train_copy.loc[:, '650_src':'990_src'].columns
train_copy2.drop(drops, axis=1, inplace=True)
train_copy2

test_copy2 = test_copy.copy()
drops = test_copy.loc[:, '650_src':'990_src'].columns
test_copy2.drop(drops, axis=1, inplace=True)
test_copy2
# Out:
#            id   rho       650_dst       660_dst       670_dst       680_dst  \
# 0     10000.0  15.0  0.000000e+00  3.514159e-15  7.028318e-15  1.199001e-14
# 9999    0.447032    0.862002    0.866738    0.445300    0.216202
#
# [10000 rows x 44 columns]

# %%
# _src 변수 제거한 후 다중공선성
feature_columns = list(train_copy2.columns.difference(['id','hhb','hbo2','ca','na']))

vif3 = pd.DataFrame()
vif3['VIF Factor'] = [variance_inflation_factor(train_copy2[feature_columns].values, i) for i in range(train_copy2[feature_columns].shape[1])]
vif3['features'] = train_copy2[feature_columns].columns

vif3.sort_values(by='VIF Factor', ascending=False)
# Out:
#     VIF Factor    features
# 24  989.989095     820_dst
# 25  854.900479     830_dst
# 23  782.108571     810_dst
# 27  770.159699     850_dst
# 26  735.941545     840_dst
# 22  567.942679     800_dst
# 20  521.015484     790_dst
# 28  435.220412     860_dst
# 29  322.447552     870_dst
# 19  306.553666     780_dst
# 30  175.882598     880_dst
# 32  105.358389     900_dst
# 18  102.670351     770_dst
# 33   88.470961     910_dst
# 34   82.314565     920_dst
# 16   69.150893     750_dst
# 17   64.924350     760_dst
# 31   46.100087     890_dst
# 15   35.386908     740_dst
# 13   30.479674     720_dst
# 10   27.310421  6_mean_src
# 3    25.717943  4_mean_src
# 4    24.933883  5_mean_src
# 2    24.030186  3_mean_src
# 1    24.011965  2_mean_src
# 14   21.389883     730_dst
# 35   14.780635     930_dst
# 12   11.016992     710_dst
# 21   10.630977  7_mean_src
# 0     9.101218  1_mean_src
# 37    7.572821     950_dst
# 38    6.563436     960_dst
# 42    5.437576         rho
# 7     3.373360     670_dst
# 8     3.175322     680_dst
# 39    2.776143     970_dst
# 36    2.273922     940_dst
# 40    2.272263     980_dst
# 6     1.969606     660_dst
# 5     1.694101     650_dst
# 41    1.689682     990_dst
# 9     1.343756     690_dst
# 11    1.016323     700_dst

# %%
# src - dst 변수 추가
src_list = train_copy.loc[:, '650_src':'990_src'].columns
dst_list = train_copy.loc[:, '650_dst':'990_dst'].columns

gap_feature_names=[]
for i in range(650, 1000, 10):
    gap_feature_names.append(str(i) + '_gap')

gap = pd.DataFrame(np.array(train_copy[src_list]) - np.array(train_copy[dst_list]), columns=gap_feature_names, index=train_copy.index)

train_copy = pd.concat((train_copy, gap), axis=1)
train_copy
# Out:
#           id   rho  650_src  660_src  670_src  680_src  690_src  700_src  \
# 0        0.0  25.0  0.37950  0.42993  0.52076  0.57166  0.67818  0.75476
# 1        1.0  10.0  0.00000  0.00000  0.01813  0.00000  0.00000  0.01974
# 2        2.0  25.0  0.00000  0.03289  0.02416  0.03610  0.05843  0.09015
# 3        3.0  10.0  0.27503  0.31281  0.32898  0.41041  0.46587  0.52769
# 4        4.0  15.0  1.01521  1.00872  0.98930  0.98874  1.01773  1.01632
# ...      ...   ...      ...      ...      ...      ...      ...      ...
# 9995  9995.0  15.0  0.23929  0.30265  0.39929  0.51000  0.64072  0.77328
# 9996  9996.0  20.0  0.02583  0.00946  0.03650  0.01380  0.04093  0.04363
# 9997  9997.0  10.0  0.57589  0.62976  0.70571  0.77248  0.85402  0.92796
# 9998  9998.0  15.0  1.01477  1.01504  0.99125  0.98747  1.00717  1.01434
# 9999  9999.0  10.0  0.24452  0.28182  0.36493  0.42131  0.50305  0.61418
#
#       710_src  720_src  ...  900_gap  910_gap  920_gap       930_gap  940_gap  \
# 0     0.83580  0.93623  ...  0.14493  0.13150  0.12442  1.078600e-01  0.11984
# 1     0.00321  0.00000  ...  0.41456  0.63716  0.84230  9.748000e-01  0.99803
# 2     0.14944  0.18578  ...  0.46222  0.39113  0.27879  1.907000e-01  0.16603
# 3     0.64369  0.73562  ...  0.17876  0.15139  0.15656  1.339200e-01  0.14247
# 4     1.00009  0.98217  ...  0.98300  1.00616  0.99045  1.013210e+00  1.01559
# ...       ...      ...  ...      ...      ...      ...           ...      ...
# 9995  0.86722  0.95891  ...  0.00000  0.00317  0.00811 -1.686503e-15  0.01942
# 9996  0.03260  0.05282  ...  0.89597  0.69515  0.53156  4.028200e-01  0.30653
# 9997  0.97691  0.98933  ...  0.19588  0.17659  0.17717  1.467000e-01  0.14668
# 9998  0.99529  1.01322  ...  0.98012  1.00746  1.00718  1.000170e+00  0.98364
# 9999  0.70350  0.78836  ...  0.11213  0.06540  0.06070  1.733000e-02  0.03542
#
#       950_gap       960_gap  970_gap  980_gap  990_gap
# 0     0.09851  1.096500e-01  0.07424  0.07777  0.05536
# 1     0.97146  8.704500e-01  0.75330  0.63414  0.53699
# 2     0.11617  6.744000e-02  0.02343  0.03926 -5.28864
# 3     0.10126  9.928000e-02  0.09239  0.10523 -2.77151
# 4     1.01072  9.943900e-01  0.98597 -2.99111 -6.96588
# ...       ...           ...      ...      ...      ...
# 9995  0.00000 -5.516467e-16  0.01132  0.00731  0.01579
# 9996  0.22199  1.717800e-01  0.15614  0.12397  0.09550
# 9997  0.11504  1.113300e-01  0.12952  0.11553  0.11319
# 9998  0.98014  9.955900e-01  1.01426  1.01546  1.00357
# 9999  0.00559  1.622000e-02  0.01188  0.00825  0.01274
#
# [10000 rows x 118 columns]

# %%
# test
src_list_test = test_copy.loc[:, '650_src':'990_src'].columns
dst_list_test = test_copy.loc[:, '650_dst':'990_dst'].columns

gap_feature_names=[]
for i in range(650, 1000, 10):
    gap_feature_names.append(str(i) + '_gap')

gap = pd.DataFrame(np.array(test_copy[src_list_test]) - np.array(test_copy[dst_list_test]), columns=gap_feature_names, index=test_copy.index)

test_copy = pd.concat((test_copy, gap), axis=1)
test_copy
# Out:
#            id   rho  650_src  660_src  670_src  680_src  690_src  700_src  \
# 0     10000.0  15.0  0.15406  0.23275  0.30977  0.42949  0.51264  0.62558
# 1     10001.0  15.0  0.48552  0.56939  0.67575  0.79089  0.85114  0.92581
# 2     10002.0  10.0  0.46883  0.56085  0.62442  0.73172  0.81724  0.91517
# 3     10003.0  10.0  0.06905  0.07517  0.10226  0.14905  0.16182  0.19659
# 4     10004.0  25.0  0.00253  0.00757  0.01649  0.00128  0.00000  0.00000
# ...       ...   ...      ...      ...      ...      ...      ...      ...
# 9995  19995.0  15.0  0.04334  0.03279  0.05853  0.04070  0.07704  0.07859
# 9996  19996.0  25.0  0.00020  0.02009  0.01726  0.03816  0.08300  0.08681
# 9997  19997.0  15.0  0.00000  0.00000  0.00120  0.00000  0.04347  0.14882
# 9998  19998.0  20.0  0.08390  0.05690  0.08343  0.12324  0.12720  0.16732
# 9999  19999.0  15.0  0.11016  0.11505  0.13086  0.12352  0.14200  0.15434
#
#       710_src  720_src  ...  900_gap  910_gap  920_gap  930_gap       940_gap  \
# 0     0.74340  0.85418  ...  0.02841  0.01290  0.00132  0.00000  0.000000e+00
# 1     0.98071  0.98177  ...  0.01144  0.00703  0.00096  0.01406 -4.825731e-14
# 2     0.94801  0.99108  ...  0.13508  0.14524  0.10918  0.10280  1.038700e-01
# 3     0.26085  0.36753  ...  0.04793  0.03783  0.04006  0.02746  4.642000e-02
# 4     0.00105  0.01975  ...  0.72828  0.83838  0.92615  0.96783  9.990200e-01
# ...       ...      ...  ...      ...      ...      ...      ...           ...
# 9995  0.06168  0.08903  ...  0.94957  1.00150  0.96775  0.92453  7.998800e-01
# 9996  0.15300  0.18099  ...  0.57224  0.49234  0.38224  0.31815  2.168600e-01
# 9997  0.40883  0.80365  ...  0.00000  0.00000  0.00234  0.01931  7.660000e-03
# 9998  0.18149  0.23766  ...  0.07686  0.08491  0.07192  0.03477  3.442000e-02
# 9999  0.18970  0.19676  ...  0.59606  0.49535  0.44616  0.37098  3.179500e-01
#
#       950_gap       960_gap       970_gap       980_gap  990_gap
# 0     0.01904 -1.429966e-14  1.952000e-02 -3.660118e-14  0.01285
# 1     0.00223  1.188000e-02 -7.348414e-14  9.100000e-03  0.00201
# 2     0.09468  6.623000e-02  8.721000e-02  6.559000e-02  0.06880
# 3     0.00630  1.501000e-02  1.071000e-02  3.310000e-02  0.01281
# 4     1.00555  9.513800e-01  9.124300e-01  8.565600e-01  0.76263
# ...       ...           ...           ...           ...      ...
# 9995  0.68060  5.934100e-01  4.773700e-01  4.215000e-01  0.34152
# 9996  0.16377  1.363500e-01  1.067500e-01  4.907000e-02  0.02410
# 9997  0.00664  9.200000e-04 -1.436617e-15  0.000000e+00  0.00953
# 9998  0.05455  4.825000e-02  2.415000e-02  1.773000e-02  0.02409
# 9999  0.26084  2.373800e-01  1.944200e-01  2.088400e-01  0.17953
#
# [10000 rows x 114 columns]

# %%
# 다시 _src 변수 제거 후 다중공선성 확인
feature_columns = list(train_copy.columns.difference(['id','hhb','hbo2','ca','na']))

vif4 = pd.DataFrame()
vif4['VIF Factor'] = [variance_inflation_factor(train_copy[feature_columns].values, i) for i in range(train_copy[feature_columns].shape[1])]
vif4['features'] = train_copy[feature_columns].columns

vif4.sort_values(by='VIF Factor', ascending=False)
# Out:
#        VIF Factor features
# 94            inf  940_dst
# 21            inf  700_dst
# 14   2.251800e+15  680_dst
# 17   6.928615e+14  690_dst
# 15   6.004800e+14  680_gap
# ..            ...      ...
# 27   5.653740e+10  720_dst
# 33   4.653032e+10  740_dst
# 30   1.756104e+10  730_dst
# 24   5.432956e+09  710_dst
# 112  6.684539e+00      rho
#
# [113 rows x 2 columns]

# %%
# _dst 변수 제거
drops = train_copy.loc[:, '650_dst':'990_dst'].columns
train_copy4 = train_copy3.drop(drops, axis=1)

feature_columns = list(train_copy4.columns.difference(['id','hhb','hbo2','ca','na']))

vif5 = pd.DataFrame()
vif5['VIF Factor'] = [variance_inflation_factor(train_copy4[feature_columns].values, i) for i in range(train_copy4[feature_columns].shape[1])]
vif5['features'] = train_copy4[feature_columns].columns

vif5.sort_values(by='VIF Factor', ascending=False)
# Out:
#       VIF Factor    features
# 18           inf     770_gap
# 29           inf     870_gap
# 27           inf     850_gap
# 26           inf     840_gap
# 23           inf     810_gap
# 20           inf     790_gap
# 16           inf     750_gap
# 28           inf     860_gap
# 2            inf  3_mean_src
# 3            inf  4_mean_src
# 4            inf  5_mean_src
# 30  9.007199e+15     880_gap
# 19  9.007199e+15     780_gap
# 25  9.007199e+15     830_gap
# 24  9.007199e+15     820_gap
# 22  9.007199e+15     800_gap
# 17  9.007199e+15     760_gap
# 31  9.007199e+15     890_gap
# 1   4.608420e+09  2_mean_src
# 14  2.015079e+08     730_gap
# 15  2.001876e+08     740_gap
# 13  1.980703e+08     720_gap
# 12  1.891796e+08     710_gap
# 11  1.763881e+08     700_gap
# 10  2.126792e+04  6_mean_src
# 35  2.259329e+03     930_gap
# 32  1.534363e+03     900_gap
# 34  1.421827e+03     920_gap
# 33  1.401704e+03     910_gap
# 0   9.584990e+02  1_mean_src
# 36  7.586227e+02     940_gap
# 8   6.267821e+02     680_gap
# 7   6.028083e+02     670_gap
# 9   6.005409e+02     690_gap
# 37  2.358197e+02     950_gap
# 6   1.700366e+02     660_gap
# 38  6.052805e+01     960_gap
# 21  4.201710e+01  7_mean_src
# 5   1.696187e+01     650_gap
# 39  7.609179e+00     970_gap
# 40  2.662739e+00     980_gap
# 41  1.456606e+00     990_gap
# 42  1.007894e+00         rho

# %%
train_2 = train_copy3
test_2 = test_copy.drop(src_list_test, axis=1)
display(train_2, test_2)
# Out:
#           id   rho   650_dst   660_dst   670_dst   680_dst   690_dst  \
# 0        0.0  25.0 -0.262033 -0.110876 -0.045925 -0.023682 -0.012889
# 1        1.0  10.0 -0.262033 -0.110876 -0.045925 -0.023682 -0.012889
# 2        2.0  25.0 -0.262033 -0.110876 -0.045925 -0.023682 -0.012889
# 3        3.0  10.0 -0.262033 -0.110876 -0.045925 -0.023682 -0.012889
# 4        4.0  15.0 -0.262033 -0.110876 -0.045925 -0.023682 -0.012889
# ...      ...   ...       ...       ...       ...       ...       ...
# 9995  9995.0  15.0 -0.262033 -0.110876 -0.045925 -0.023682 -0.012889
# 9996  9996.0  20.0  0.334694 -0.110876 -0.045925 -0.023682 -0.012889
# 9997  9997.0  10.0 -0.262033 -0.110876 -0.045925 -0.023682 -0.012889
# 9998  9998.0  15.0 -0.262033 -0.110876 -0.045925 -0.023682 -0.012889
# 9999  9999.0  10.0 -0.262033 -0.110876 -0.045925 -0.023682 -0.012889
#
#        700_dst   710_dst   720_dst  ...   900_gap   910_gap   920_gap  \
# 0    -0.010001 -0.081863 -0.102228  ... -0.807714 -0.777074 -0.728394
# 1    -0.010001 -0.081863 -0.102228  ... -0.093998  0.549586  1.154481
# 2    -0.010001 -0.081863 -0.102228  ...  0.032159 -0.095904 -0.323508
# 3    -0.010000 -0.077029  0.423935  ... -0.718165 -0.724891 -0.644096
# 4    -0.010001 -0.081217 -0.102228  ...  1.410673  1.517702  1.543053
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995 -0.010001 -0.081795 -0.101951  ... -1.191346 -1.113764 -1.033455
# 9996 -0.010001 -0.081863 -0.102228  ...  1.180303  0.701730  0.339464
# 9997 -0.010001 -0.081863 -0.062929  ... -0.672848 -0.658775 -0.590039
# 9998 -0.010001 -0.081863 -0.101495  ...  1.403050  1.521113  1.586933
# 9999 -0.010001 -0.039502 -0.102228  ... -0.894536 -0.950496 -0.895520
#
#        930_gap   940_gap   950_gap   960_gap   970_gap   980_gap   990_gap
# 0    -0.704714 -0.603761 -0.588085 -0.470619 -0.392589 -0.035314  0.374281
# 1     1.595092  1.774922  1.839318  1.682149  1.322693  0.758796  0.627384
# 2    -0.484957 -0.478650 -0.538978 -0.590057 -0.520933 -0.090279 -2.434066
# 3    -0.635582 -0.542465 -0.580438 -0.499962 -0.346743  0.003880 -1.111279
# 4     1.696986  1.822485  1.948488  2.032851  1.910409 -4.415545 -3.315479
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -0
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

train_copy2 = train_copy.copy()
test_copy2 = test_copy.copy()

scaler = StandardScaler()
m_scaler = MinMaxScaler()

src_col = train_copy2.filter(regex='_src$', axis=1).columns
dst_col = train_copy2.filter(regex='_dst$', axis=1).columns
gap_col = train_copy2.filter(regex='_gap$', axis=1).columns

# src_col, gap_col
train_copy2[src_col] = scaler.fit_transform(train_copy2[src_col])
test_copy2[src_col] = scaler.transform(test_copy2[src_col])
train_copy2[gap_col] = scaler.fit_transform(train_copy2[gap_col])
test_copy2[gap_col] = scaler.transform(test_copy2[gap_col])

# dst_col
train_copy2[dst_col] = m_scaler.fit_transform(train_copy2[dst_col])
test_copy2[dst_col] = m_scaler.transform(test_copy2[dst_col])

# %% [markdown]
# # 4. 모델 학습 및 검증

# %%
x_train = train.loc[:, 'rho':'990_dst']
y_train = train.loc[:, 'hhb':'na']
test.drop('id', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-307-8f56173a145f> in <module>
#       9 x_train = train.loc[:, 'rho':'990_dst']
#      10 y_train = train.loc[:, 'hhb':'na']
# ---> 11 test.drop('id', axis=1, inplace=True)
#
# C:\Users\hyun\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# C:\Users\hyun\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# C:\Users\hyun\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# C:\Users\hyun\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['id'] not found in axis"

# %%
train_copy = train.copy()
test_copy = test.copy()

ntrain = train_copy.shape[0]
ntest = test_copy.shape[0]

all_data = pd.concat((train_copy, test_copy)).reset_index(drop=True)
all_data.drop(['id', 'hhb', 'hbo2', 'ca', 'na'], axis=1, inplace=True)
all_data.head()
# Out:
#         650_dst   650_src       660_dst   660_src       670_dst   670_src  \
# 0  3.015579e-18  0.730404  3.112100e-18  0.784356  0.000000e+00  0.949828
# 1  0.000000e+00 -0.660493  0.000000e+00 -0.705114  0.000000e+00 -0.691011
# 2  2.066572e-19 -0.660493  6.182204e-20 -0.591168  4.636653e-20 -0.671326
# 3  4.983313e-11  0.347514  7.712448e-11  0.378600  1.317072e-10  0.323761
# 4  5.894699e-14  3.060331  3.929799e-14  2.789542  0.000000e+00  2.479380
#
#         680_dst   680_src       690_dst   690_src  ...   950_src  \
# 0  3.160222e-17  0.962038  1.443636e-16  1.133961  ... -0.596792
# 1  9.833784e-10 -0.797819  1.347312e-09 -0.847026  ...  1.853599
# 2  0.000000e+00 -0.686685  3.934316e-18 -0.676350  ... -0.547220
# 3  4.487787e-11  0.465629  2.472458e-10  0.513796  ... -0.589073
# 4  5.682314e-13  2.246020  0.000000e+00  2.125799  ...  1.963803
#
#         960_dst   960_src       970_dst   970_src       980_dst   980_src  \
# 0  9.470887e-20 -0.500250  1.330223e-19 -0.544647  5.606494e-19 -0.475339
# 1  3.780438e-10  1.746627  7.377344e-10  1.581476  9.074851e-10  1.383250
# 2  0.000000e+00 -0.624910  0.000000e+00 -0.703732  1.242733e-19 -0.603984
# 3  1.380947e-11 -0.530876  3.032513e-11 -0.487819  3.821421e-11 -0.383607
# 4  1.958174e-14  2.112660  1.657616e-14  2.309962  3.728972e-01  2.601720
#
#         990_dst   990_src   rho
# 0  3.273655e-18 -0.495426  25.0
# 1  3.629941e-10  1.216150  10.0
# 2  3.977570e-01 -0.580715  25.0
# 3  2.119626e-01 -0.466534  10.0
# 4  5.966355e-01  2.911735  15.0
#
# [5 rows x 71 columns]

# %%
# skew()함수 이용해 모든 숫자형 변수들의 skew 확인

from scipy.stats import skew

skewed_feats = all_data.apply(
    lambda x: skew(x.dropna())).sort_values(ascending=False)

print("\nSkew in all data: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(15)
# Out:
# Skew in all data:
#                Skew
# 940_dst  141.410749
# 700_dst  116.509600
# 690_dst   90.490380
# 950_dst   79.764179
# 960_dst   58.165142
# 680_dst   57.833830
# 710_dst   51.103984
# 730_dst   31.835651
# 720_dst   29.616548
# 670_dst   28.832798
# 740_dst   27.369241
# 850_dst   24.547338
# 840_dst   23.981241
# 970_dst   23.954605
# 750_dst   23.922205

# %%
from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    all_data[feat] = boxcox1p(all_data[feat], lam)

# %% [markdown]
# # xgboost (with skew)

# %%
train_skew = all_data[:ntrain]
test_skew = all_data[ntrain:]

train_skew.shape, test_skew.shape
# Out:
# ((10000, 71), (10000, 71))

# %%
x_train.head()
# Out:
#     rho   650_src   660_src   670_src   680_src   690_src   700_src   710_src  \
# 0  25.0  0.730404  0.784356  0.949828  0.962038  1.133961  1.209218  1.300369
# 1  10.0 -0.660493 -0.705114 -0.691011 -0.797819 -0.847026 -0.845735 -0.947247
# 2  25.0 -0.660493 -0.591168 -0.671326 -0.686685 -0.676350 -0.648885 -0.552492
# 3  10.0  0.347514  0.378600  0.323761  0.465629  0.513796  0.574380  0.781759
# 4  15.0  3.060331  2.789542  2.479380  2.246020  2.125799  1.940482  1.743878
#
#     720_src   730_src  ...       900_dst       910_dst       920_dst  \
# 0  1.455641  1.440823  ...  2.635335e-10  2.903106e-10  1.618852e-10
# 1 -1.014398 -1.079002  ...  2.267751e-01  3.243167e-01  4.060570e-01
# 2 -0.524258 -0.409790  ...  3.964938e-10  1.159979e-10  2.511906e-10
# 3  0.926375  1.010063  ...  1.091957e-02  5.036030e-03  8.828707e-03
# 4  1.576843  1.577653  ...  0.000000e+00  6.327475e-07  1.193013e-06
#
#         930_dst       940_dst       950_dst       960_dst       970_dst  \
# 0  4.609028e-11  1.718211e-19  0.000000e+00  9.470887e-20  1.330223e-19
# 1  9.026178e-01  7.149751e-09  1.626950e-09  3.780438e-10  7.377344e-10
# 2  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 3  1.187953e-02  1.195588e-10  3.458774e-11  1.380947e-11  3.032513e-11
# 4  3.567328e-06  7.760978e-14  2.333968e-14  1.958174e-14  1.657616e-14
#
#         980_dst       990_dst
# 0  5.606494e-19  3.273655e-18
# 1  9.074851e-10  3.629941e-10
# 2  1.242733e-19  3.977570e-01
# 3  3.821421e-11  2.119626e-01
# 4  3.728972e-01  5.966355e-01
#
# [5 rows x 71 columns]

# %%
train_skew.isnull().sum().plot()

# %%
test.head()
# Out:
#     rho   650_src   660_src   670_src   680_src   690_src   700_src   710_src  \
# 0  15.0 -0.095851  0.101236  0.261050  0.524367  0.650413  0.848059  1.050931
# 1  15.0  1.118976  1.267507  1.455794  1.636938  1.639183  1.687436  1.691561
# 2  10.0  1.057806  1.237921  1.288227  1.454783  1.540160  1.657689  1.603285
# 3  10.0 -0.407419 -0.444691 -0.416368 -0.338968 -0.374344 -0.351302 -0.251735
# 4  25.0 -0.651220 -0.678888 -0.696365 -0.793879 -0.847026 -0.900924 -0.953078
#
#     720_src   730_src  ...   900_dst   910_dst   920_dst   930_dst  \
# 0  1.239170  1.296487  ...  0.000000  0.000000  0.000001  0.000000
# 1  1.575788  1.502163  ...  0.000009  0.000005  0.000002  0.000008
# 2  1.600350  1.569727  ...  0.001136  0.001141  0.001123  0.001077
# 3 -0.044750  0.266328  ...  0.001414  0.000599  0.000389  0.000740
# 4 -0.962291 -1.079002  ...  0.000000  0.000000  0.000000  0.000000
#
#         940_dst       950_dst       960_dst       970_dst       980_dst  \
# 0  0.000000e+00  1.685354e-15  2.537328e-15  0.000000e+00  3.420671e-15
# 1  2.568830e-14  9.459603e-15  4.050037e-15  9.156903e-15  1.176687e-14
# 2  8.353200e-12  1.661469e-12  1.635328e-12  1.519016e-12  1.139262e-12
# 3  8.362858e-12  0.000000e+00  0.000000e+00  4.117442e-13  3.837508e-12
# 4  1.986646e-17  1.094077e-17  0.000000e+00  0.000000e+00  1.785771e-17
#
#         990_dst
# 0  5.473074e-15
# 1  1.756915e-14
# 2  9.114097e-13
# 3  3.070007e-12
# 4  1.656578e-16
#
# [5 rows x 71 columns]

# %%
sns.set()
for col in train_skew.columns:
    fig,ax = plt.subplots(1, 1, figsize=(20,4))
    sns.distplot(train_skew[col])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-308-dec0cb2d7bc5> in <module>
#       2 for col in train_skew.columns:
#       3     fig,ax = plt.subplots(1, 1, figsize=(20,4))
# ----> 4     sns.distplot(train_skew[col])
#
# C:\Users\hyun\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# C:\Users\hyun\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ValueError: cannot convert float NaN to integer

# %%
sns.set()
for col in columns:
    fig,ax = plt.subplots(1, 1, figsize=(20,4))
    sns.distplot(train[col])

# %%
# skew까지 하고 나서 xgboost_2

def train_model(x_data, y_data, k=5):
    models = []
    
    k_fold = KFold(n_splits=k, shuffle=True, random_state=123)
    
    for train_idx, val_idx in k_fold.split(x_data):
        x_train, y_train = x_data.iloc[train_idx], y_data[train_idx]
        x_val, y_val = x_data.iloc[val_idx], y_data[val_idx]
    
        d_train = xgb.DMatrix(data = x_train, label = y_train)
        d_val = xgb.DMatrix(data = x_val, label = y_val)
        
        wlist = [(d_train, 'train'), (d_val, 'eval')]
        
        params = {
            'max_depth': 7,
            'learning_rate' : 0.3,
            'objective': 'reg:squarederror',
            'eval_metric': 'mae',
            'subsample' : 0.5,
            'colsample_bytree': 0.8,
            'seed': 777
            }

        model = xgb.train(params=params, dtrain=d_train, num_boost_round=1000, early_stopping_rounds=100, verbose_eval=500, evals=wlist)
        models.append(model)
    
    return models

# %%
test_skew.head()
# Out:
#             650_dst   650_src       660_dst   660_src       670_dst   670_src  \
# 10000  0.000000e+00 -0.100003  5.772480e-15  0.097134  1.731744e-14  0.236026
# 10001  1.237485e-03  0.794859  6.151341e-13  0.871071  2.933070e-14  0.961805
# 10002  2.134032e-12  0.762146  3.001690e-11  0.856236  3.284127e-11  0.881363
# 10003  0.000000e+00 -0.503259  0.000000e+00 -0.563026  0.000000e+00 -0.517311
# 10004  0.000000e+00 -0.974319  6.620170e-17 -1.044454  8.045087e-17 -1.091453
#
#             680_dst   680_src       690_dst   690_src  ...   950_src  \
# 10000  5.908564e-14  0.435195  2.227654e-13  0.520333  ... -1.511436
# 10001  4.499926e-12  1.043677  2.361108e-13  1.044661  ... -1.741046
# 10002  1.301796e-11  0.961334  4.597653e-11  1.000553  ... -0.872679
# 10003  1.337172e-11 -0.401364  8.630767e-11 -0.452841  ... -1.679758
# 10004  1.231984e-16 -1.406165  0.000000e+00 -1.636280  ...  1.174242
#
#             960_dst   960_src       970_dst   970_src       980_dst   980_src  \
# 10000  2.537328e-15 -1.529712  0.000000e+00 -1.147005  3.420671e-15 -1.204531
# 10001  4.050037e-15 -1.387656  9.156903e-15 -1.344016  1.176687e-14 -1.114783
# 10002  1.635328e-12 -0.920139  1.519016e-12 -0.665634  1.139262e-12 -0.687621
# 10003  0.000000e+00 -1.353595  4.117442e-13 -1.230946  3.837508e-12 -0.911082
# 10004  0.000000e+00  1.188661  0.000000e+00  1.225299  1.785771e-17  1.243078
#
#             990_dst   990_src       rho
# 10000  5.473074e-15 -0.962816  3.438110
# 10001  1.756915e-14 -1.060683  3.438110
# 10002  9.114097e-13 -0.567939  2.885846
# 10003  3.070007e-12 -0.963160  2.885846
# 10004  1.656578e-16  1.201379  4.201461
#
# [5 rows x 71 columns]

# %%
x_train_skew = train_skew
y_train_skew = train.loc[:, 'hhb':'na']

# %%
models = {}
for label in y_train_skew.columns:
    print('train column : ', label)
    models[label] = train_model(x_train_skew, y_train_skew[label])
    print('\n\n')
# Out:
# train column :  hhb
# [0]	train-mae:5.30369	eval-mae:5.28915
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [80]	train-mae:0.34137	eval-mae:1.04827
#
# [0]	train-mae:5.30914	eval-mae:5.25212
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [76]	train-mae:0.34327	eval-mae:1.02389
#
# [0]	train-mae:5.29913	eval-mae:5.31300
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [54]	train-mae:0.46259	eval-mae:1.00727
#
# [0]	train-mae:5.28216	eval-mae:5.31019
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [62]	train-mae:0.41137	eval-mae:1.06037
#
# [0]	train-mae:5.28018	eval-mae:5.34146
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [41]	train-mae:0.49845	eval-mae:1.02619
#
#
#
#
# train column :  hbo2
# [0]	train-mae:2.45969	eval-mae:2.47255
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [18]	train-mae:0.51892	eval-mae:0.71713
#
# [0]	train-mae:2.46331	eval-mae:2.48187
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [26]	train-mae:0.47647	eval-mae:0.71276
#
# [0]	train-mae:2.47122	eval-mae:2.43078
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [10]	train-mae:0.59921	eval-mae:0.72926
#
# [0]	train-mae:2.46381	eval-mae:2.48368
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [25]	train-mae:0.47644	eval-mae:0.72105
#
# [0]	train-mae:2.46920	eval-mae:2.46577
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [11]	train-mae:0.57770	eval-mae:0.74411
#
#
#
#
# train column :  ca
# [0]	train-mae:6.01694	eval-mae:6.11207
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [15]	train-mae:1.62476	eval-mae:2.14693
#
# [0]	train-mae:6.01529	eval-mae:6.03510
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [17]	train-mae:1.59595	eval-mae:2.13007
#
# [0]	train-mae:6.02725	eval-mae:6.08881
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [12]	train-mae:1.72570	eval-mae:2.13632
#
# [0]	train-mae:6.04252	eval-mae:5.91758
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [13]	train-mae:1.64405	eval-mae:2.10880
#
# [0]	train-mae:6.02678	eval-mae:6.04490
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [16]	train-mae:1.61152	eval-mae:2.11008
#
#
#
#
# train column :  na
# [0]	train-mae:2.06667	eval-mae:1.97419
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 100 rounds.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-53172fe5eefe> in <module>
#       2 for label in y_train_skew.columns:
#       3     print('train column : ', label)
# ----> 4     models[label] = train_model(x_train_skew, y_train_skew[label])
#       5     print('\n\n')
#
# <ipython-input-142-3ad830c8adca> in train_model(x_data, y_data, k)
#      25             }
#      26
# ---> 27         model = xgb.train(params=params, dtrain=d_train, num_boost_round=1000, early_stopping_rounds=100, verbose_eval=500, evals=wlist)
#      28         models.append(model)
#      29
#
# C:\Users\hyun\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     207                            evals=evals,
#     208                            obj=obj, feval=feval,
# --> 209                            xgb_model=xgb_model, callbacks=callbacks)
#     210
#     211
#
# C:\Users\hyun\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# C:\Users\hyun\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1247             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1248                                                     ctypes.c_int(iteration),
# -> 1249                                                     dtrain.handle))
#    1250         else:
#    1251             pred = self.predict(dtrain, training=True)
#
# KeyboardInterrupt:

# %%
# # bagging(데이터 복원추출) 후 lgb 적용 반복

# import random

# def train_model(x_data, y_data, k=5):
#     models = []
    
#     k_fold = KFold(n_splits=k, shuffle=True, random_state=123)
    
#     bagging_predict_model = []
    
#     for train_idx, val_idx in k_fold.split(x_data):
#         x_train, y_train = x_data.iloc[train_idx], y_data[train_idx]
#         x_val, y_val = x_data.iloc[val_idx], y_data[val_idx]
        
#         models = []

#         for _ in range(30): 
#             train_data_index = [train_data_index for train_data_index in range(x_train.shape[0])] # x_train 개수만큼
#             random_data_index = np.random.choice(train_data_index, x_train.shape[0]) #추출할 변수:train_data_index, 추출할 요소의 개수:x_train.shape[0]
            
#             val_data_index = [val_data_index for val_data_index in range(x_val.shape[0])]
#             random_data_index2 = np.random.choice(val_data_index, x_val.shape[0])
            
#             d_train = lgb.Dataset(data = x_train.iloc[random_data_index], label = y_train.iloc[random_data_index])
#             d_val = lgb.Dataset(data = x_val.iloc[random_data_index2], label = y_val.iloc[random_data_index2])

#             wlist = {}

#             params = {
#                 'objective': 'regression',
#                 'metric': 'mae',
#                 'seed':777,
#             }

#             model = lgb.train(params=params,
#                               train_set=d_train,
#                               num_boost_round=500,
#                               verbose_eval=100,
#                               evals_result=wlist)
            
#             models.append(model)
            
#             #predict1 = model.predict(lgb.Dataset(test))
#             #bagging_predict.append(predict1)
        
#         bagging_predict_model.append(models)
#         #bagging_predict_result.append(np.mean(bagging_predict))
        
#             #models.append(model)
    
#     return bagging_predict_model

# %%
# models_predict = {}
# for label in y_train.columns:
#     print('train column : ', label)
#     models_predict[label] = train_model(x_train, y_train[label])
# Out:
# train column :  hhb
# train column :  hbo2
# train column :  ca
# train column :  na

# %%
# models_predict
#    <lightgbm.basic.Booster at 0x19ec2a23668>,
#    <lightgbm.basic.Booster at 0x19ec2a231d0>,
#    <lightgbm.basic.Booster at 0x19ec2a0f668>,
#    <lightgbm.basic.Booster at 0x19ec2a0fc18>,
#    <lightgbm.basic.Booster at 0x19ecd1065c0>,
#    <lightgbm.basic.Booster at 0x19ec270b9e8>,
#    <lightgbm.basic.Booster at 0x19ec2a0fc88>,
#    <lightgbm.basic.Booster at 0x19ed0888048>,
#    <lightgbm.basic.Booster at 0x19ec2a0fd30>,
#    <lightgbm.basic.Booster at 0x19ec2a0f4e0>,
#    <lightgbm.basic.Booster at 0x19ec2a23710>,
#    <lightgbm.basic.Booster at 0x19ec2a23860>,
#    <lightgbm.basic.Booster at 0x19ec2a23a58>,
#    <lightgbm.basic.Booster at 0x19ec2a234a8>,
#    <lightgbm.basic.Booster at 0x19ec2a23eb8>,
#    <lightgbm.basic.Booster at 0x19ec2a23240>],
#   [<lightgbm.basic.Booster at 0x19ec2a23048>,
#    <lightgbm.basic.Booster at 0x19ecd106e10>,
#    <lightgbm.basic.Booster at 0x19ec2a714a8>,
#    <lightgbm.basic.Booster at 0x19ec2a71e10>,
#    <lightgbm.basic.Booster at 0x19ec2a715c0>,
#    <lightgbm.basic.Booster at 0x19ec28e5be0>,
#    <lightgbm.basic.Booster at 0x19ec28e54a8>,
#    <lightgbm.basic.Booster at 0x19ec2a711d0>,
#    <lightgbm.basic.Booster at 0x19ec28e5a58>,
#    <lightgbm.basic.Booster at 0x19ec2a71a20>,
#    <lightgbm.basic.Booster at 0x19ec2b762e8>,
#    <lightgbm.basic.Booster at 0x19ec28e5978>,
#    <lightgbm.basic.Booster at 0x19ec2a23c88>,
#    <lightgbm.basic.Booster at 0x19ecff1a7b8>,
#    <lightgbm.basic.Booster at 0x19ec28e52b0>,
#    <lightgbm.basic.Booster at 0x19ec2a23a90>,
#    <lightgbm.basic.Booster at 0x19ec2a0f160>,
#    <lightgbm.basic.Booster at 0x19ec2a0fe10>,
#    <lightgbm.basic.Booster at 0x19ec2b76f60>,
#    <lightgbm.basic.Booster at 0x19ec2b76198>,
#    <lightgbm.basic.Booster at 0x19ec28e5a20>,
#    <lightgbm.basic.Booster at 0x19ec2bfae48>,
#    <lightgbm.basic.Booster at 0x19ec2a230b8>,
#    <lightgbm.basic.Booster at 0x19ec28e5828>,
#    <lightgbm.basic.Booster at 0x19ec2be7f60>,
#    <lightgbm.basic.Booster at 0x19ec28b6240>,
#    <lightgbm.basic.Booster at 0x19ec28e5ba8>,
#    <lightgbm.basic.Booster at 0x19ec2ba79e8>,
#    <lightgbm.basic.Booster at 0x19ec419e080>,
#    <lightgbm.basic.Booster at 0x19ec419e630>]],
#  'hbo2': [[<lightgbm.basic.Booster at 0x19ecff1a390>,
#    <lightgbm.basic.Booster at 0x19ecff1a0f0>,
#    <lightgbm.basic.Booster at 0x19ed0bcb3c8>,
#    <lightgbm.basic.Booster at 0x19ec2a71048>,
#    <lightgbm.basic.Booster at 0x19ec2a71780>,
#    <lightgbm.basic.Booster at 0x19ed1e0fcf8>,
#    <lightgbm.basic.Booster at 0x19ed1dc6c50>,
#    <lightgbm.basic.Booster at 0x19ed1dc6c88>,
#    <lightgbm.basic.Booster at 0x19ed1dc67b8>,
#    <lightgbm.basic.Booster at 0x19ed1dc6d30>,
#    <lightgbm.basic.Booster at 0x19ed1dc6630>,
#    <lightgbm.basic.Booster at 0x19ed1dc6400>,
#    <lightgbm.basic.Booster at 0x19ed1dc66a0>,
#    <lightgbm.basic.Booster at 0x19ed1dc6ba8>,
#    <lightgbm.basic.Booster at 0x19ed1dc6a58>,
#    <lightgbm.basic.Booster at 0x19ed1dc6eb8>,
#    <lightgbm.basic.Booster at 0x19ed1dc68d0>,
#    <lightgbm.basic.Booster at 0x19ed1dc6710>,
#    <lightgbm.basic.Booster at 0x19ed1dc6f60>,
#    <lightgbm.basic.Booster at 0x19ed1e11240>,
#    <lightgbm.basic.Booster at 0x19ed1e11080>,
#    <lightgbm.basic.Booster at 0x19ed1e114e0>,
#    <lightgbm.basic.Booster at 0x19ed1e11518>,
#    <lightgbm.basic.Booster at 0x19ed1e11358>,
#    <lightgbm.basic.Booster at 0x19ed1dc6ef0>,
#    <lightgbm.basic.Booster at 0x19ed1dc6438>,
#    <lightgbm.basic.Booster at 0x19ed1d58fd0>,
#    <lightgbm.basic.Booster at 0x19ec2bf17b8>,
#    <lightgbm.basic.Booster at 0x19ed1e0fef0>,
#    <lightgbm.basic.Booster at 0x19ed1dc6780>,
#    <lightgbm.basic.Booster at 0x19ed0888f98>,
#    <lightgbm.basic.Booster at 0x19ed1dc6fd0>,
#    <lightgbm.basic.Booster at 0x19ed1dc66d8>]]}

# %%
# for col in models_predict:
#     print(col)
#     preds = []
#     for model_list in models_predict[col]:
#         for i in range(len(model_list)):
#             preds.append(model_list[i].predict(test))

#     preds_result = np.mean(preds, axis=0)
#     submission[col] = preds_result
# Out:
# hhb
# hbo2
# ca
# na

# %%
# submission.head()
# Out:
#       id       hhb      hbo2         ca        na
# 0  10000  8.005074  4.474275   8.571544  3.569099
# 1  10001  5.473688  4.246903   8.571602  2.606729
# 2  10002  9.048577  4.801982  10.261452  3.535404
# 3  10003  7.702145  4.524639  11.151717  3.284557
# 4  10004  8.446068  3.281861   7.964039  4.134805

# %%
# submission.to_csv('4_Dacon_bio_lgb.csv', index=False)

# %% [markdown]
# - 리더보드 점수 : 1.4431578511

# %% [markdown]
# # LightGBM 2

# %%
# 2

def train_model(x_data, y_data, k=5):
    models = []
    
    k_fold = KFold(n_splits=k, shuffle=True, random_state=123)
    
    for train_idx, val_idx in k_fold.split(x_data):
  
        x_train, y_train = x_data.iloc[train_idx,:], y_data[train_idx]
        x_val, y_val = x_data.iloc[val_idx,:], y_data[val_idx]

        d_train = lgb.Dataset(data = np.array(x_train), label =(y_train))
 
        d_val = lgb.Dataset(data = np.array(x_val), label = np.array(y_val))

        wlist = {}
       
        params = {
            'max_depth':20,
            'learning_rate':0.1,
            'num_leaves':100,
            'objective':'regression',
            'metric':'mae',
            'seed':777,
            'feature_fraction':0.8,
            'bagging_fraction':0.8,
            'num_boost_round':10000,
            'early_stopping_rounds':50
            }

        model = lgb.train(params=params,
                          train_set=d_train,
                          valid_sets = [d_train, d_val],
                          valid_names = ['train', 'eval'],
                          verbose_eval=100,
                          evals_result=wlist)
        
        models.append(model)
    
    return models

# %%
models = {}
for label in y_train.columns:
    print('train column : ', label)
    models[label] = train_model(x_train, y_train[label])
    print('\n\n')
# Out:
# train column :  hhb
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.301238	eval's l1: 0.83397
# [200]	train's l1: 0.133277	eval's l1: 0.817526
# [300]	train's l1: 0.0650926	eval's l1: 0.814635
# [400]	train's l1: 0.0324323	eval's l1: 0.813546
# [500]	train's l1: 0.0166278	eval's l1: 0.813111
# Early stopping, best iteration is:
# [492]	train's l1: 0.0176099	eval's l1: 0.813079
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.302656	eval's l1: 0.804844
# [200]	train's l1: 0.133875	eval's l1: 0.793798
# [300]	train's l1: 0.0647607	eval's l1: 0.7906
# [400]	train's l1: 0.0327476	eval's l1: 0.789846
# Early stopping, best iteration is:
# [389]	train's l1: 0.0353076	eval's l1: 0.789725
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.302933	eval's l1: 0.803868
# [200]	train's l1: 0.136594	eval's l1: 0.787226
# [300]	train's l1: 0.0658296	eval's l1: 0.783811
# [400]	train's l1: 0.0329956	eval's l1: 0.782195
# [500]	train's l1: 0.0167851	eval's l1: 0.781445
# [600]	train's l1: 0.00889426	eval's l1: 0.781105
# [700]	train's l1: 0.00477081	eval's l1: 0.780966
# Early stopping, best iteration is:
# [697]	train's l1: 0.00485976	eval's l1: 0.78096
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.297425	eval's l1: 0.812597
# [200]	train's l1: 0.131832	eval's l1: 0.797282
# [300]	train's l1: 0.0637267	eval's l1: 0.79494
# [400]	train's l1: 0.0319396	eval's l1: 0.794069
# [500]	train's l1: 0.0160099	eval's l1: 0.793084
# [600]	train's l1: 0.00833404	eval's l1: 0.792811
# Early stopping, best iteration is:
# [647]	train's l1: 0.00616452	eval's l1: 0.792748
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.301639	eval's l1: 0.83566
# [200]	train's l1: 0.135328	eval's l1: 0.820577
# [300]	train's l1: 0.0654001	eval's l1: 0.816772
# [400]	train's l1: 0.0330763	eval's l1: 0.815656
# [500]	train's l1: 0.017066	eval's l1: 0.814717
# [600]	train's l1: 0.0089705	eval's l1: 0.814438
# Early stopping, best iteration is:
# [589]	train's l1: 0.00960621	eval's l1: 0.814363
#
#
#
# train column :  hbo2
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.246452	eval's l1: 0.627235
# [200]	train's l1: 0.112398	eval's l1: 0.620302
# [300]	train's l1: 0.056198	eval's l1: 0.618178
# Early stopping, best iteration is:
# [349]	train's l1: 0.0401349	eval's l1: 0.618112
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.245623	eval's l1: 0.615111
# [200]	train's l1: 0.11349	eval's l1: 0.608378
# [300]	train's l1: 0.0556021	eval's l1: 0.606036
# [400]	train's l1: 0.0287721	eval's l1: 0.605199
# [500]	train's l1: 0.014631	eval's l1: 0.604662
# [600]	train's l1: 0.00783095	eval's l1: 0.604652
# [700]	train's l1: 0.00422974	eval's l1: 0.604528
# Early stopping, best iteration is:
# [720]	train's l1: 0.00371725	eval's l1: 0.604505
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.493241	eval's l1: 1.27564
# [200]	train's l1: 0.231012	eval's l1: 1.26798
# Early stopping, best iteration is:
# [179]	train's l1: 0.269365	eval's l1: 1.26749

# %%
for col in models:
    preds = []
    for model in models[col]:
        preds.append(model.predict(test))
    pred = np.mean(preds, axis=0)

    submission[col] = pred

# %%
submission.head()
# Out:
#       id       hhb      hbo2         ca        na
# 0  10000  8.608163  4.514646   9.316729  3.779909
# 1  10001  6.492141  3.503804   8.572464  2.988432
# 2  10002  9.673231  5.440983  10.150897  4.139341
# 3  10003  8.484264  4.141213  10.538485  3.400969
# 4  10004  6.716666  3.517080   8.303691  4.209946

# %%
submission.to_csv('5_Dacon_bio_lgb2.csv', index=False)

# %% [markdown]
# - 리더보드 점수 : 1.1699360463

# %%
# 3

def train_model(x_data, y_data, k=5):
    models = []
    
    k_fold = KFold(n_splits=k, shuffle=True, random_state=123)
    
    for train_idx, val_idx in k_fold.split(x_data):
  
        x_train, y_train = x_data.iloc[train_idx,:], y_data[train_idx]
        x_val, y_val = x_data.iloc[val_idx,:], y_data[val_idx]

        d_train = lgb.Dataset(data = np.array(x_train), label =(y_train))
 
        d_val = lgb.Dataset(data = np.array(x_val), label = np.array(y_val))

        wlist = {}
       
        params = {
            'max_depth':25,
            'learning_rate':0.1,
            'num_leaves':110,
            'max_bin':250,
            'objective':'regression',
            'metric':'mae',
            'seed':777,
            'feature_fraction':0.6,
            'bagging_fraction':0.8,
            'num_boost_round':10000,
            'early_stopping_rounds':50
            }

        model = lgb.train(params=params,
                          train_set=d_train,
                          valid_sets = [d_train, d_val],
                          valid_names = ['train', 'eval'],
                          verbose_eval=100,
                          evals_result=wlist,)
        
        models.append(model)
    
    return models

# %%
models = {}
lgbm_oof_train = {}
lgbm_oof_test = {}
for label in y_train.columns:
    print('train column : ', label)
    models[label], lgbm_oof_train[label], lgbm_oof_test[label] = train_model(x_train, y_train[label])
    print('\n\n')
# Out:
# train column :  hhb
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.282784	eval's l1: 0.835724
# [200]	train's l1: 0.120687	eval's l1: 0.822888
# [300]	train's l1: 0.0568216	eval's l1: 0.819739
# [400]	train's l1: 0.0272408	eval's l1: 0.818601
# Early stopping, best iteration is:
# [431]	train's l1: 0.0218057	eval's l1: 0.818409
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.287573	eval's l1: 0.813188
# [200]	train's l1: 0.122656	eval's l1: 0.800472
# [300]	train's l1: 0.0567516	eval's l1: 0.796883
# [400]	train's l1: 0.0269037	eval's l1: 0.796152
# [500]	train's l1: 0.0131713	eval's l1: 0.795618
# [600]	train's l1: 0.0064816	eval's l1: 0.795553
# [700]	train's l1: 0.00324381	eval's l1: 0.795383
# Early stopping, best iteration is:
# [723]	train's l1: 0.00277829	eval's l1: 0.795354
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.285582	eval's l1: 0.818385
# [200]	train's l1: 0.122623	eval's l1: 0.802993
# [300]	train's l1: 0.0566996	eval's l1: 0.799132
# [400]	train's l1: 0.0277902	eval's l1: 0.798233
# Early stopping, best iteration is:
# [430]	train's l1: 0.0222528	eval's l1: 0.797864
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.280677	eval's l1: 0.824194
# [200]	train's l1: 0.119467	eval's l1: 0.808014
# [300]	train's l1: 0.0549834	eval's l1: 0.805064
# [400]	train's l1: 0.0263166	eval's l1: 0.804445
# [500]	train's l1: 0.0129213	eval's l1: 0.804348
# [600]	train's l1: 0.00638011	eval's l1: 0.8042
# Early stopping, best iteration is:
# [588]	train's l1: 0.00694951	eval's l1: 0.804175
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.733463	eval's l1: 1.94858
# [200]	train's l1: 0.335801	eval's l1: 1.94204
# [300]	train's l1: 0.163498	eval's l1: 1.94019
# Early stopping, best iteration is:
# [312]	train's l1: 0.149168	eval's l1: 1.93867
#
#
#
# train column :  na
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.462453	eval's l1: 1.25591
# [200]	train's l1: 0.203758	eval's l1: 1.2496
# [300]	train's l1: 0.0935291	eval's l1: 1.24834
# [400]	train's l1: 0.0446449	eval's l1: 1.24747
# Early stopping, best iteration is:
# [355]	train's l1: 0.0620602	eval's l1: 1.2472
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.458365	eval's l1: 1.26947
# [200]	train's l1: 0.204254	eval's l1: 1.26083
# Early stopping, best iteration is:
# [193]	train's l1: 0.215014	eval's l1: 1.26015
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.463323	eval's l1: 1.26147
# [200]	train's l1: 0.203616	eval's l1: 1.25873
# Early stopping, best iteration is:
# [159]	train's l1: 0.282247	eval's l1: 1.25639
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.464229	eval's l1: 1.26282
# [200]	train's l1: 0.206929	eval's l1: 1.26149
# Early stopping, best iteration is:
# [157]	train's l1: 0.289197	eval's l1: 1.26048
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.46061	eval's l1: 1.25606
# [200]	train's l1: 0.204753	eval's l1: 1.25579
# Early stopping, best iteration is:
# [167]	train's l1: 0.266756	eval's l1: 1.25444

# %%
for col in models:
    preds = []
    for model in models[col]:
        preds.append(model.predict(test))
    pred = np.mean(preds, axis=0)

    submission[col] = pred

# %%
submission.to_csv('7_Dacon_bio_lgb4.csv', index=False)

# %% [markdown]
# - 리더보드 점수 : 1.1615214245

# %% [markdown]
# ## (나중) skew한 데이터들로 위 모델 똑같이 돌려보자 !

# %% [markdown]
# # LightGBM3 (skew & 변수 삭제/추가)

# %%
train_feature = train_copy2.columns.difference(['id','hhb','hbo2','ca','na'])
x_train2 = train_copy2[train_feature]
y_train2 = train_copy2.loc[:, 'hhb':'na']
test_2 = test_copy2.drop('id', axis=1)

display(x_train2)
display(y_train2)
display(test_2)
# Out:
#       1_mean_src  2_mean_src  3_mean_src  4_mean_src  5_mean_src  \
# 0       0.934306    1.419557    1.011161   -0.232604   -0.730515
# 1      -0.754476   -1.025157   -1.382462   -1.582483   -1.227196
# 2      -0.666507   -0.505675    0.281011    1.303237    0.835591
# 3       0.415569    0.935464    1.305839    0.196239   -0.635424
# 4       2.542514    1.698972    1.476211    1.412718    1.472558
# ...          ...         ...         ...         ...         ...
# 9995    0.612568    1.463910    0.868143   -0.756791   -1.341265
# 9996   -0.683026   -0.913735   -1.186016   -0.997193    0.683297
# 9997    1.565699    1.621818    0.878937   -0.162609   -0.658415
# 9998    2.539877    1.711902    1.443242    1.441214    1.475412
# 9999    0.430420    1.078598    1.378242    0.520638   -0.668210
#
#            650_dst   650_gap   650_src       660_dst   660_gap  ...  \
# 0     3.015579e-18  0.801001  0.730404  3.112100e-18  0.793821  ...
# 1     0.000000e+00 -0.579124 -0.660493  0.000000e+00 -0.696126  ...
# 2     2.066572e-19 -0.579124 -0.660493  6.182204e-20 -0.582143  ...
# 3     4.983313e-11  0.421076  0.347514  7.712448e-11  0.387935  ...
# 4     5.894699e-14  3.112884  3.060331  3.929799e-14  2.799651  ...
# ...            ...       ...       ...           ...       ...  ...
# 9996  25.0 -0.659760 -0.635513 -0.693851 -0.680344 -0.604580 -0.658222
# 9997  15.0 -0.660493 -0.705114 -0.746279 -0.797819 -0.720049 -0.484856
# 9998  20.0 -0.352993 -0.507987 -0.477839 -0.418424 -0.475470 -0.433134
# 9999  15.0 -0.256748 -0.306529 -0.323003 -0.417562 -0.432239 -0.469423
#
#        710_src   720_src   730_src  ...   900_gap   910_gap   920_gap  \
# 0     1.050931  1.239170  1.296487  ... -1.116145 -1.088236 -1.051264
# 1     1.691561  1.575788  1.502163  ... -1.161064 -1.103637 -1.052208
# 2     1.603285  1.600350  1.569727  ... -0.833787 -0.741026 -0.768365
# 3    -0.251735 -0.044750  0.266328  ... -1.064475 -1.022829 -0.949655
# 4    -0.953078 -0.962291 -1.079002  ...  0.736425  1.077511  1.374405
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995 -0.789404 -0.779511 -0.847953  ...  1.322183  1.505476  1.483515
# 9996 -0.542882 -0.536895 -0.441362  ...  0.323384  0.169633 -0.052176
# 9997  0.147744  1.105857  1.567582  ... -1.191346 -1.122081 -1.048588
# 9998 -0.465972 -0.387384 -0.257475  ... -0.987896 -0.899309 -0.866092
# 9999 -0.443808 -0.495289 -0.425013  ...  0.386436  0.177530  0.115475
#
#        930_gap   940_gap   950_gap   960_gap   970_gap   980_gap   990_gap
# 0    -0.990843 -0.928362 -0.809067 -0.780886 -0.530810 -0.146316  0.351941
# 1    -0.953545 -0.928362 -0.855810 -0.747270 -0.580117 -0.133327  0.346245
# 2    -0.718137 -0.647018 -0.598735 -0.593481 -0.359827 -0.052699  0.381344
# 3    -0.917998 -0.802628 -0.844493 -0.738414 -0.553064 -0.099072  0.351920
# 4     1.576602  1.777604  1.934112  1.911149  1.724650  1.076258  0.745961
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  1.461737  1.238209  1.030527  0.898233  0.625703  0.455294  0.524662
# 9996 -0.146859 -0.340971 -0.406617 -0.395069 -0.310470 -0.076278  0.357853
# 9997 -0.939618 -0.907614 -0.843547 -0.778283 -0.580117 -0.146316  0.350197
# 9998 -0.898606 -0.835132 -0.710324 -0.644358 -0.519115 -0.121009  0.357848
# 9999 -0.006713 -0.067157 -0.136696 -0.109193 -0.089018  0.151763  0.439534
#
# [10000 rows x 113 columns]

# %%
train_skew = x_train2.copy()
test_skew = test_2.copy()

ntrain = train_skew.shape[0]
ntest = test_skew.shape[0]

all_data = pd.concat((train_skew, test_skew)).reset_index(drop=True)
all_data.head()
# Out:
#    1_mean_src  2_mean_src  3_mean_src  4_mean_src  5_mean_src   650_dst  \
# 0    0.509382    0.888078    0.831963    0.442303    0.240300 -0.262033
# 1    0.003579    0.007076    0.005625    0.002936    0.072499 -0.262033
# 2    0.029927    0.194282    0.579897    0.942199    0.769400 -0.262033
# 3    0.354016    0.713625    0.933694    0.581886    0.272426 -0.262033
# 4    0.991052    0.988771    0.992510    0.977833    0.984595 -0.262033
#
#     650_gap   660_dst   660_gap   670_dst  ...   950_gap   960_dst   960_gap  \
# 0  0.801001 -0.110876  0.793821 -0.045925  ... -0.588085 -0.030114 -0.470619
# 1 -0.579124 -0.110876 -0.696126 -0.045925  ...  1.839318 -0.030114  1.682149
# 2 -0.579124 -0.110876 -0.582143 -0.045925  ... -0.538978 -0.030114 -0.590057
# 3  0.421076 -0.110876  0.387935 -0.045925  ... -0.580438 -0.030114 -0.499962
# 4  3.112884 -0.110876  2.799651 -0.045925  ...  1.948488 -0.030114  2.032851
#
#     970_dst   970_gap   980_dst   980_gap   990_dst   990_gap   rho
# 0 -0.078456 -0.392589 -0.184944 -0.035314 -0.453210  0.374281  25.0
# 1 -0.078456  1.322693 -0.184944  0.758796 -0.453210  0.627384  10.0
# 2 -0.078456 -0.520933 -0.184944 -0.090279  2.377925 -2.434066  25.0
# 3 -0.078456 -0.346743 -0.184944  0.003880  1.055487 -1.111279  10.0
# 4 -0.078456  1.910409  6.092543 -4.415545  3.793492 -3.315479  15.0
#
# [5 rows x 78 columns]

# %%
# skew()함수 이용해 모든 숫자형 변수들의 skew 확인

from scipy.stats import skew

skewed_feats = all_data.apply(
    lambda x: skew(x.dropna())).sort_values(ascending=False)

print("\nSkew in all data: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(15)
# Out:
# Skew in all data:
#                Skew
# 940_dst  141.400142
# 700_dst  141.400142
# 690_dst  129.186779
# 950_dst   79.746216
# 680_dst   75.141314
# 710_dst   75.040809
# 960_dst   58.140825
# 670_dst   48.708765
# 720_dst   42.480037
# 730_dst   41.169313
# 850_dst   39.229062
# 740_dst   38.758805
# 840_dst   37.570465
# 750_dst   34.100093
# 860_dst   33.628250

# %%
from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    all_data[feat] = boxcox1p(all_data[feat], lam)

# %%
train_skew = all_data[:ntrain]
test_skew = all_data[ntrain:]

train_skew.shape, test_skew.shape
# Out:
# ((10000, 78), (10000, 78))

# %%
def train_model(x_data, y_data, k=5):
    models = []
    
    k_fold = KFold(n_splits=k, shuffle=True, random_state=123)
    
    for train_idx, val_idx in k_fold.split(x_data):
  
        x_train, y_train = x_data.iloc[train_idx,:], y_data[train_idx]
        x_val, y_val = x_data.iloc[val_idx,:], y_data[val_idx]

        d_train = lgb.Dataset(data = np.array(x_train), label =(y_train))
 
        d_val = lgb.Dataset(data = np.array(x_val), label = np.array(y_val))

        wlist = {}
       
        params = {
            'max_depth':25,
            'learning_rate':0.1,
            'num_leaves':110,
            'max_bin':250,
            'objective':'regression',
            'metric':'mae',
            'seed':777,
            'feature_fraction':0.6,
            'bagging_fraction':0.8,
            'num_boost_round':10000,
            'early_stopping_rounds':50
            }

        model = lgb.train(params=params,
                          train_set=d_train,
                          valid_sets = [d_train, d_val],
                          valid_names = ['train', 'eval'],
                          verbose_eval=100,
                          evals_result=wlist,)
        
        models.append(model)
    
    return models

# %%
# skew한 상태
# skew 안한 이전 lgb 모델보다 아주 약~간 차이남
models = {}
for label in y_train2.columns:
    print('train column : ', label)
    models[label] = train_model(train_skew, y_train2[label])
    print('\n\n')
# Out:
# train column :  hhb
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.284854	eval's l1: 0.842269
# [200]	train's l1: 0.119902	eval's l1: 0.831049
# [300]	train's l1: 0.0542118	eval's l1: 0.827148
# [400]	train's l1: 0.0255809	eval's l1: 0.825398
# Early stopping, best iteration is:
# [430]	train's l1: 0.0206492	eval's l1: 0.825041
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.286881	eval's l1: 0.803543
# [200]	train's l1: 0.119962	eval's l1: 0.795814
# [300]	train's l1: 0.0544934	eval's l1: 0.792739
# Early stopping, best iteration is:
# [301]	train's l1: 0.0541264	eval's l1: 0.792733
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.2877	eval's l1: 0.829923
# [200]	train's l1: 0.122513	eval's l1: 0.81448
# [300]	train's l1: 0.0563052	eval's l1: 0.810425
# [400]	train's l1: 0.0269245	eval's l1: 0.80866
# [500]	train's l1: 0.0132619	eval's l1: 0.807914
# [600]	train's l1: 0.00664699	eval's l1: 0.807575
# [700]	train's l1: 0.00338596	eval's l1: 0.807395
# [800]	train's l1: 0.00176295	eval's l1: 0.807311
# [900]	train's l1: 0.000958101	eval's l1: 0.807285
# [1000]	train's l1: 0.000528531	eval's l1: 0.807267
# Early stopping, best iteration is:
# [1017]	train's l1: 0.00047962	eval's l1: 0.807264
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.285089	eval's l1: 0.833499
# [200]	train's l1: 0.119799	eval's l1: 0.821083
# [300]	train's l1: 0.0547971	eval's l1: 0.818567
# [400]	train's l1: 0.0256111	eval's l1: 0.817591
# [500]	train's l1: 0.0125388	eval's l1: 0.817093
# [600]	train's l1: 0.00621851	eval's l1: 0.816855
# Early stopping, best iteration is:
# [600]	train's l1: 0.00621851	eval's l1: 0.816855
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.28753	eval's l1: 0.844728
# [200]	train's l1: 0.122293	eval's l1: 0.833384
# [300]	train's l1: 0.0561867	eval's l1: 0.831531
# [400]	train's l1: 0.0268735	eval's l1: 0.830913
# [500]	train's l1: 0.0128796	eval's l1: 0.830618
# Early stopping, best iteration is:
# [531]	train's l1: 0.0104024	eval's l1: 0.830579
#
#
#
# train column :  hbo2
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.229557	eval's l1: 0.635797
# [200]	train's l1: 0.0995492	eval's l1: 0.629318
# [300]	train's l1: 0.0462819	eval's l1: 0.628916
# Early stopping, best iteration is:
# [301]	train's l1: 0.0459364	eval's l1: 0.628851
# Training until validation scores don't improve for 50 rounds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-548-034a16b02f11> in <module>
#       2 for label in y_train2.columns:
#       3     print('train column : ', label)
# ----> 4     models[label] = train_model(train_skew, y_train2[label])
#       5     print('\n\n')
#
# <ipython-input-547-0bf31bc3f612> in train_model(x_data, y_data, k)
#      34                           valid_names = ['train', 'eval'],
#      35                           verbose_eval=100,
# ---> 36                           evals_result=wlist,)
#      37
#      38         models.append(model)
#
# C:\Users\hyun\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     247                                     evaluation_result_list=None))
#     248
# --> 249         booster.update(fobj=fobj)
#     250
#     251         evaluation_result_list = []
#
# C:\Users\hyun\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    1974             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1975                 self.handle,
# -> 1976                 ctypes.byref(is_finished)))
#    1977             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1978             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
# skew 안한 상태
models = {}
for label in y_train2.columns:
    print('train column : ', label)
    models[label] = train_model(x_train2, y_train2[label])
    print('\n\n')
# Out:
# train column :  hhb
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.274339	eval's l1: 0.835218
# [200]	train's l1: 0.115964	eval's l1: 0.819944
# [300]	train's l1: 0.0522998	eval's l1: 0.816693
# [400]	train's l1: 0.0245222	eval's l1: 0.815704
# Early stopping, best iteration is:
# [418]	train's l1: 0.0214557	eval's l1: 0.81565
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.224999	eval's l1: 0.641716
# [200]	train's l1: 0.097574	eval's l1: 0.636339
# [300]	train's l1: 0.0444723	eval's l1: 0.633275
# [400]	train's l1: 0.0216276	eval's l1: 0.632407
# [500]	train's l1: 0.0104718	eval's l1: 0.632113
# Early stopping, best iteration is:
# [547]	train's l1: 0.0074744	eval's l1: 0.632041
#
#
#
# train column :  ca
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.710887	eval's l1: 1.94952
# [200]	train's l1: 0.312873	eval's l1: 1.94308
# Early stopping, best iteration is:
# [185]	train's l1: 0.351138	eval's l1: 1.94086
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.712754	eval's l1: 1.96488
# [200]	train's l1: 0.314288	eval's l1: 1.96097
# Early stopping, best iteration is:
# [170]	train's l1: 0.400434	eval's l1: 1.96017
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.718147	eval's l1: 1.97633
# Early stopping, best iteration is:
# [121]	train's l1: 0.601683	eval's l1: 1.9697
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.716914	eval's l1: 1.90799
# Early stopping, best iteration is:
# [132]	train's l1: 0.546883	eval's l1: 1.90504
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.721393	eval's l1: 1.9512
# [200]	train's l1: 0.32225	eval's l1: 1.94541
# Early stopping, best iteration is:
# [201]	train's l1: 0.319981	eval's l1: 1.94516
#
#
#
# train column :  na
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.456623	eval's l1: 1.25952
# Early stopping, best iteration is:
# [117]	train's l1: 0.393286	eval's l1: 1.25532
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.456487	eval's l1: 1.25338
# Early stopping, best iteration is:
# [145]	train's l1: 0.308949	eval's l1: 1.24686
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.452274	eval's l1: 1.23948
# Early stopping, best iteration is:
# [116]	train's l1: 0.394647	eval's l1: 1.23555
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.458954	eval's l1: 1.27595
# Early stopping, best iteration is:
# [147]	train's l1: 0.312345	eval's l1: 1.27331
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.453097	eval's l1: 1.28236
# Early stopping, best iteration is:
# [113]	train's l1: 0.404037	eval's l1: 1.27957

# %%
submission_prev = submission.copy()

# for col in models:
#     preds = []
#     for model in models[col]:
#         preds.append(model.predict(test))
#     pred = np.mean(preds, axis=0)

#     submission_prev[col] = pred
    
submission_prev.drop('id', axis=1, inplace=True)

# %%
# 실제값과 예측값의 분포 비교
fig, axes = plt.subplots(1, 1, figsize=(10, 8), sharex=True, sharey=True)

# y=x를 그리기 위하여
x_range = np.linspace(0, 300, 1000)

# 예측/실제값 비교
axes.scatter(y_train, submission_prev )
axes.set_xlabel("Prediction")
axes.set_ylabel("Real")

# y=x 그리기
axes.plot(x_range, x_range, color='r');

# Super Title 
plt.suptitle('Comparison between Prediction VS Real');

# %%
# 실제값 vs 예측값 비교

# hhb
plt.figure(figsize=(12,6))
sns.distplot(submission_prev['hhb'], color='r', label='Prediction for Train')
sns.distplot(y_train['hhb'], color='b', label='Real' )
plt.legend()
plt.title("Comparing the real vs prediction in Local-Train");

# %%
# 실제값 vs 예측값 비교

# hbo2
plt.figure(figsize=(12,6))
sns.distplot(submission_prev['hbo2'], color='r', label='Prediction for Train')
sns.distplot(y_train['hbo2'], color='b', label='Real' )
plt.legend()
plt.title("Comparing the real vs prediction in Local-Train");

# %%
# 실제값 vs 예측값 비교

# ca
plt.figure(figsize=(12,6))
sns.distplot(submission_prev['ca'], color='r', label='Prediction for Train')
sns.distplot(y_train['ca'], color='b', label='Real' )
plt.legend()
plt.title("Comparing the real vs prediction in Local-Train");

# %%
# 실제값 vs 예측값 비교

# na
plt.figure(figsize=(12,6))
sns.distplot(submission_prev['na'], color='r', label='Prediction for Train')
sns.distplot(y_train['na'], color='b', label='Real' )
plt.legend()
plt.title("Comparing the real vs prediction in Local-Train");

# %%
# base_model parameter

NUM_BOOST_ROUND = 100000
SEED = 1993
lgbm_param = {'num_boost_round':10000,
              'objective':'regression',
              'metric':'mae',
              'random_state':1993,
              'learning_rate':0.1, 
              'subsample':0.7, 
              'feature_fraction':0.8,
              'bagging_fraction':0.7,
              'tree_learner': 'serial',
              'early_stopping_rounds':50,
              'subsample_freq': 1,
              'reg_lambda': 7,
              'reg_alpha': 5,
              'num_leaves': 96,
              'seed' : SEED
            }

# params = {
#             'max_depth':10,
#             'learning_rate':0.2,
#             'num_leaves':100,
#             'objective':'regression',
#             'metric':'mae',
#             'seed':777,
#             'feature_fraction':0.8,
#             'bagging_fraction':0.7,
#             'subsample':0.5,
#             'reg_lambda': 7,
#             'reg_alpha': 6,
#             'max_bin':250
#             }

# %%
# base_model parameter

from bayes_opt import BayesianOptimization

NUM_BOOST_ROUND = 100000
SEED = 1993
lgbm_param = {'objective':'regression',
              'metric':'mae',
              'boosting_type': 'gbdt',
              'learning_rate':0.3, 
              'subsample':0.7, 
              'feature_fraction':0.8,
              'bagging_fraction':0.7,
              'tree_learner': 'serial',
              'early_stopping_rounds':50,
              'subsample_freq': 1,
              'reg_lambda':7,
              'reg_alpha': 5,
              'num_leaves': 96,
              'seed' : SEED
            }

# %%
# 과적합 줄이기위한 lgb

def train_model(x_data, y_data, k=5):
    models = []
    
    k_fold = KFold(n_splits=k, shuffle=True, random_state=123)
    
    for train_idx, val_idx in k_fold.split(x_data):
  
        x_train, y_train = x_data.iloc[train_idx,:], y_data[train_idx]
        x_val, y_val = x_data.iloc[val_idx,:], y_data[val_idx]

        d_train = lgb.Dataset(data = np.array(x_train), label =(y_train))
 
        d_val = lgb.Dataset(data = np.array(x_val), label = np.array(y_val))

        wlist = {}
       
        params = {
            'max_depth':10,
            'learning_rate':0.2,
            'num_leaves':100,
            'objective':'regression',
            'metric':'mae',
            'seed':777,
            'feature_fraction':0.8,
            'bagging_fraction':0.7,
            'subsample':0.5,
            'reg_lambda': 7,
            'reg_alpha': 6,
            'max_bin':250
            }

        model = lgb.train(params=params,
                          train_set=d_train,
                          valid_sets = [d_train, d_val],
                          valid_names = ['train', 'eval'],
                          num_boost_round=10000,
                          verbose_eval=100,
                          evals_result=wlist,
                          early_stopping_rounds=50)
        
        models.append(model)
    
    return models

# %%
# models = {}
# for label in y_train.columns:
#     print('train column : ', label)
#     models[label] = train_model(x_train, y_train[label])
#     print('\n\n')
# Out:
# train column :  hhb
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.292153	eval's l1: 0.846367
# [200]	train's l1: 0.179069	eval's l1: 0.835255
# [300]	train's l1: 0.1553	eval's l1: 0.831988
# Early stopping, best iteration is:
# [281]	train's l1: 0.155568	eval's l1: 0.831952
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.29465	eval's l1: 0.811284
# [200]	train's l1: 0.181084	eval's l1: 0.799144
# [300]	train's l1: 0.158801	eval's l1: 0.797169
# Early stopping, best iteration is:
# [271]	train's l1: 0.158813	eval's l1: 0.797167
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.296599	eval's l1: 0.825182
# [200]	train's l1: 0.184326	eval's l1: 0.813832
# Early stopping, best iteration is:
# [240]	train's l1: 0.16512	eval's l1: 0.811677
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.29382	eval's l1: 0.833307
# [200]	train's l1: 0.181255	eval's l1: 0.819966
# [300]	train's l1: 0.151718	eval's l1: 0.818043
# Early stopping, best iteration is:
# [276]	train's l1: 0.151718	eval's l1: 0.818043
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.292388	eval's l1: 0.868905
# [200]	train's l1: 0.179802	eval's l1: 0.858715
# [300]	train's l1: 0.157854	eval's l1: 0.854959
# Early stopping, best iteration is:
# [269]	train's l1: 0.157854	eval's l1: 0.854959
#
#
#
# train column :  hbo2
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.256373	eval's l1: 0.628178
# [200]	train's l1: 0.168402	eval's l1: 0.622434
# Early stopping, best iteration is:
# [245]	train's l1: 0.154856	eval's l1: 0.620047
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.259861	eval's l1: 0.615794
# [200]	train's l1: 0.170366	eval's l1: 0.610342
# [300]	train's l1: 0.157433	eval's l1: 0.608955
# Early stopping, best iteration is:
# [251]	train's l1: 0.157451	eval's l1: 0.608944
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.256159	eval's l1: 0.631769
# [200]	train's l1: 0.172171	eval's l1: 0.625637
# [300]	train's l1: 0.15897	eval's l1: 0.623628
# Early stopping, best iteration is:
# [257]	train's l1: 0.158975	eval's l1: 0.623628
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.252529	eval's l1: 0.626829
# [200]	train's l1: 0.171443	eval's l1: 0.61915
# Early stopping, best iteration is:
# [205]	train's l1: 0.169465	eval's l1: 0.618783
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.255714	eval's l1: 0.658221
# [200]	train's l1: 0.173726	eval's l1: 0.650561
# [300]	train's l1: 0.156857	eval's l1: 0.649545
# Early stopping, best iteration is:
# [262]	train's l1: 0.157191	eval's l1: 0.649406
#
#
#
# train column :  ca
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.657738	eval's l1: 1.98111
# [200]	train's l1: 0.310627	eval's l1: 1.9782
# Early stopping, best iteration is:
# [213]	train's l1: 0.287881	eval's l1: 1.97618
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.633732	eval's l1: 1.99967
# Early stopping, best iteration is:
# [119]	train's l1: 0.53484	eval's l1: 1.99778
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.631056	eval's l1: 1.99011
# Early stopping, best iteration is:
# [52]	train's l1: 0.998674	eval's l1: 1.98944
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.62415	eval's l1: 1.91495
# Early stopping, best iteration is:
# [55]	train's l1: 0.978091	eval's l1: 1.91184
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.675583	eval's l1: 1.95789
# Early stopping, best iteration is:
# [78]	train's l1: 0.808594	eval's l1: 1.95338
#
#
#
# train column :  na
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.442916	eval's l1: 1.2746
# [200]	train's l1: 0.234001	eval's l1: 1.27323
# Early stopping, best iteration is:
# [171]	train's l1: 0.273022	eval's l1: 1.27177
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.456651	eval's l1: 1.28178
# Early stopping, best iteration is:
# [78]	train's l1: 0.552402	eval's l1: 1.27961
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.444352	eval's l1: 1.28297
# Early stopping, best iteration is:
# [110]	train's l1: 0.412307	eval's l1: 1.28187
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.456002	eval's l1: 1.30506
# Early stopping, best iteration is:
# [121]	train's l1: 0.387538	eval's l1: 1.29928
# Training until validation scores don't improve for 50 rounds
# [100]	train's l1: 0.447975	eval's l1: 1.28755
# Early stopping, best iteration is:
# [75]	train's l1: 0.553208	eval's l1: 1.28531

# %%
# for col in models:
#     preds = []
#     for model in models[col]:
#         preds.append(model.predict(test))
#     pred = np.mean(preds, axis=0)

#     submission[col] = pred

# %%
# submission.head()
# Out:
#       id       hhb      hbo2         ca        na
# 0  10000  8.816494  4.587496   8.963769  3.660325
# 1  10001  6.185302  3.383711   8.346663  2.863978
# 2  10002  9.438506  5.500983  10.021658  4.068062
# 3  10003  8.725741  4.157567  10.805627  4.096737
# 4  10004  6.372040  3.221068   8.611849  3.981258

# %%
# submission.to_csv('6_Dacon_bio_lgb3.csv', index=False)

# %% [markdown]
# - 리더보드 점수 : 1.1773185871

# %% [markdown]
# ## BASELINE MODEL 만들기
#
# 아래와 같은 모델들을 만들어보고, 어떤 타입의 모델이 본 문제를 풀기 적합한가 살펴보도록 하자.
# 추가적으로 linear model에서는 coefficient를 통하여, tree-based model에서는 feature_importance를 통하여 변수의 중요도를 살펴보며,
# 향후 모델의 성능을 높이기 위해선 어떤 방법이 있을까 생각해보자.
#
# - Linear Regression
#     - Ridge
#     - Lasso
# - Tree-Based
#     - Decision Tree
#     - Random Forest
#     - Light GBM

# %% [markdown]
# ## Feature Importance

# %%
# hhb

plt.figure(figsize=(24,5))
plt.bar(train.drop(['id', 'hhb', 'hbo2', 'ca', 'na'], axis=1).columns, models['hhb'][3].feature_importance())
# y=0인 horizental한 선을 그린다.
plt.axhline(y=0, color='r', linestyle='-')
plt.xticks(rotation=45)
plt.title("Coef of LightGBM Model");

# %%
# hbo2

plt.figure(figsize=(24,5))
plt.bar(train.drop(['id', 'hhb', 'hbo2', 'ca', 'na'], axis=1).columns, models['hbo2'][0].feature_importance())
# y=0인 horizental한 선을 그린다.
plt.axhline(y=0, color='r', linestyle='-')
plt.xticks(rotation=45)
plt.title("Coef of LightGBM Model");

# %%
# ca

plt.figure(figsize=(24,5))
plt.bar(train.drop(['id', 'hhb', 'hbo2', 'ca', 'na'], axis=1).columns, models['ca'][0].feature_importance())
# y=0인 horizental한 선을 그린다.
plt.axhline(y=0, color='r', linestyle='-')
plt.xticks(rotation=45)
plt.title("Coef of LightGBM Model");

# %%
# na

plt.figure(figsize=(24,5))
plt.bar(train.drop(['id', 'hhb', 'hbo2', 'ca', 'na'], axis=1).columns, models['na'][0].feature_importance())
# y=0인 horizental한 선을 그린다.
plt.axhline(y=0, color='r', linestyle='-')
plt.xticks(rotation=45)
plt.title("Coef of LightGBM Model");

# %% [markdown]
# ### PDP PLOT
#
# PDP(Partial Dependency Plot)을 통하여 특정 칼럼의 값이 변할 때 Target Variable이 어떤 식으로 영향을 받는지 살펴보자

# %%
sample = train.drop(['id', 'hhb', 'hbo2', 'ca', 'na'], axis=1).sample(1000)
